# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# %%
path = './school_data/'

# %%
school = pd.read_csv(path+'위해지표_전처리_출입금지(200m).csv')
school.head(10)
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   학교명                 320 non-null    object
#  1   학교코드                320 non-null    object
#  2   지역                  320 non-null    object
#  3   법정동코드               320 non-null    int64
#  4   위도                  320 non-null    float64
#  5   경도                  320 non-null    float64
#  6   개최횟수                320 non-null    int64
#  7   심의건수                320 non-null    int64
#  8   학교장의 자체해결건수         320 non-null    int64
#  9   피해학생수               320 non-null    int64
#  10  피해학생_보호조치건수         320 non-null    int64
#  11  가해학생수               320 non-null    int64
#  12  선도·교육
# 조치건수          320 non-null    int64
#  13  신체폭력                320 non-null    int64
#  14  언어폭력                320 non-null    int64
#  15  금품갈취                320 non-null    int64
#  16  강요                  320 non-null    int64
#  17  따돌림                 320 non-null    int64
#  18  성폭력                 320 non-null    int64
#  19  사이버폭력               320 non-null    int64
#  20  기타                  320 non-null    int64
#  21  학교폭력유형건수_합계         320 non-null    int64
#  22  200미터내_청소년출입금지업소개수  320 non-null    int64
# dtypes: float64(2), int64(18), object(3)
# memory usage: 57.6+ KB

# %%
school['학교폭력유형건수_합계'].value_counts()
# Out:
# 0     59
# 1     50
# 2     39
# 3     36
# 4     36
# 5     29
# 6     20
# 7      9
# 8      8
# 12     6
# 11     5
# 9      4
# 13     4
# 15     3
# 10     2
# 14     2
# 16     2
# 20     2
# 17     1
# 19     1
# 22     1
# 29     1
# Name: 학교폭력유형건수_합계, dtype: int64

# %%
school_info = school[['학교코드','학교명','지역','법정동코드','위도','경도']]
df = school.iloc[:,6:]
labels= np.array(school['학교코드'])

# %%
df.corr()
# Out:
#                         개최횟수      심의건수  학교장의 자체해결건수     피해학생수  피해학생_보호조치건수  \
# 개최횟수                1.000000  0.657802     0.361863  0.558343     0.416174
# 심의건수                0.657802  1.000000     0.545479  0.714648     0.550975
# 학교장의 자체해결건수         0.361863  0.545479     1.000000  0.468200     0.379631
# 피해학생수               0.558343  0.714648     0.468200  1.000000     0.801331
# 피해학생_보호조치건수         0.416174  0.550975     0.379631  0.801331     1.000000
# 가해학생수               0.535145  0.710222     0.401913  0.710578     0.571813
# 선도·교육\n조치건수         0.543969  0.672056     0.375402  0.670935     0.583642
# 신체폭력                0.597475  0.725236     0.444303  0.590542     0.481926
# 언어폭력                0.358901  0.493437     0.314859  0.413154     0.394817
# 금품갈취                0.198729  0.245761     0.168255  0.251098     0.205837
# 강요                  0.224753  0.394138     0.455615  0.478213     0.418531
# 따돌림                 0.191970  0.336648     0.333571  0.351087     0.416336
# 성폭력                 0.328218  0.445430     0.232731  0.445020     0.359587
# 사이버폭력               0.236426  0.358849     0.225357  0.395398     0.283404
# 기타                  0.038156  0.103229     0.064213  0.094197     0.113385
# 학교폭력유형건수_합계         0.613103  0.816773     0.541419  0.736382     0.635212
# 200미터내_청소년출입금지업소개수 -0.010517 -0.019904    -0.015814 -0.064370    -0.054803
#
#                        가해학생수  선도·교육\n조치건수      신체폭력      언어폭력      금품갈취  \
# 개최횟수                0.535145     0.543969  0.597475  0.358901  0.198729
# 심의건수                0.710222     0.672056  0.725236  0.493437  0.245761
# 학교장의 자체해결건수         0.401913     0.375402  0.444303  0.314859  0.168255
# 피해학생수               0.710578     0.670935  0.590542  0.413154  0.251098
# 피해학생_보호조치건수         0.571813     0.583642  0.481926  0.394817  0.205837
# 가해학생수               1.000000     0.884803  0.663406  0.505229  0.250123
# 선도·교육\n조치건수         0.884803     1.000000  0.676578  0.507559  0.294954
# 신체폭력                0.663406     0.676578  1.000000  0.453201  0.429416
# 언어폭력                0.505229     0.507559  0.453201  1.000000  0.122855
# 금품갈취                0.250123     0.294954  0.429416  0.122855  1.000000
# 강요                  0.319188     0.301998  0.236045  0.270585  0.250517
# 따돌림                 0.294078     0.240097  0.123324  0.184536  0.059202
# 성폭력                 0.390969     0.432791  0.306680  0.155812  0.149296
# 사이버폭력               0.276046     0.257744  0.127943  0.111663  0.047487
# 기타                  0.098494     0.081542 -0.001797 -0.005535  0.038735
# 학교폭력유형건수_합계         0.750871     0.759752  0.853334  0.695545  0.462641
# 200미터내_청소년출입금지업소개수 -0.030659    -0.014678 -0.034809 -0.018390 -0.001083
#
#                           강요       따돌림       성폭력     사이버폭력        기타  \
# 개최횟수                0.224753  0.191970  0.328218  0.236426  0.038156
# 심의건수                0.394138  0.336648  0.445430  0.358849  0.103229
# 학교장의 자체해결건수         0.455615  0.333571  0.232731  0.225357  0.064213
# 피해학생수               0.478213  0.351087  0.445020  0.395398  0.094197
# 피해학생_보호조치건수         0.418531  0.416336  0.359587  0.283404  0.113385
# 가해학생수               0.319188  0.294078  0.390969  0.276046  0.098494
# 선도·교육\n조치건수         0.301998  0.240097  0.432791  0.257744  0.081542
# 신체폭력                0.236045  0.123324  0.306680  0.127943 -0.001797
# 언어폭력                0.270585  0.184536  0.155812  0.111663 -0.005535
# 금품갈취                0.250517  0.059202  0.149296  0.047487  0.038735
# 강요                  1.000000  0.271845  0.134822  0.199278  0.091682
# 따돌림                 0.271845  1.000000  0.260884  0.182742 -0.039509
# 성폭력                 0.134822  0.260884  1.000000  0.170459  0.098401
# 사이버폭력               0.199278  0.182742  0.170459  1.000000 -0.054091
# 기타                  0.091682 -0.039509  0.098401 -0.054091  1.000000
# 학교폭력유형건수_합계         0.470491  0.353034  0.510521  0.333740  0.113472
# 200미터내_청소년출입금지업소개수 -0.058840  0.048422 -0.070744  0.026845 -0.013782
#
#                     학교폭력유형건수_합계  200미터내_청소년출입금지업소개수
# 개최횟수                   0.613103           -0.010517
# 심의건수                   0.816773           -0.019904
# 학교장의 자체해결건수            0.541419           -0.015814
# 피해학생수                  0.736382           -0.064370
# 피해학생_보호조치건수            0.635212           -0.054803
# 가해학생수                  0.750871           -0.030659
# 선도·교육\n조치건수            0.759752           -0.014678
# 신체폭력                   0.853334           -0.034809
# 언어폭력                   0.695545           -0.018390
# 금품갈취                   0.462641           -0.001083
# 강요                     0.470491           -0.058840
# 따돌림                    0.353034            0.048422
# 성폭력                    0.510521           -0.070744
# 사이버폭력                  0.333740            0.026845
# 기타                     0.113472           -0.013782
# 학교폭력유형건수_합계            1.000000           -0.038561
# 200미터내_청소년출입금지업소개수    -0.038561            1.000000

# %%
# model 사용변수 선정

df = df[['학교폭력유형건수_합계','200미터내_청소년출입금지업소개수','개최횟수','심의건수','피해학생수','가해학생수','신체폭력']]

# %% [markdown]
# ***
# ## K-Means Clustering

# %%
# 표준화
sd = StandardScaler()
df_sd = pd.DataFrame(sd.fit_transform(df))
df_sd.index = labels

# %%
# silhouette_score : 군집타당성 점수 = 1에 가까울수록 군집이 잘 이루어짐

from sklearn.metrics import silhouette_score

k_range = range(2, 20)

best_n = -1
best_silhouette_score = -1

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=2021)
    kmeans.fit(df_sd)
    clusters = kmeans.predict(df_sd)
    
    score = silhouette_score(df_sd, clusters)
    print('k: ', k, 'score: ', score)
    
    if score > best_silhouette_score:
        best_n = k
        best_silhouette_score = score
        
print('best n: ', best_n, 'best score: ', best_silhouette_score)
# Out:
# k:  2 score:  0.5062103112027584
# k:  3 score:  0.3141625555869077
# k:  4 score:  0.3416260069007815
# k:  5 score:  0.314701548562123
# k:  6 score:  0.3126366419713412
# k:  7 score:  0.2904997606640421
# k:  8 score:  0.2765245428853543
# k:  9 score:  0.28992512306437523
# k:  10 score:  0.24374768037430408
# k:  11 score:  0.25634253651046335
# k:  12 score:  0.2244719449512227
# k:  13 score:  0.26796649743060763
# k:  14 score:  0.24832958444852365
# k:  15 score:  0.2388118114615855
# k:  16 score:  0.26252728368431943
# k:  17 score:  0.22180276941775787
# k:  18 score:  0.2253946723284605
# k:  19 score:  0.25937401273768723
# best n:  2 best score:  0.5062103112027584

# %%
# elbow method

dist =[]
for i in range(1,20):
    k = KMeans(n_clusters=i,init='k-means++',
           n_init=10, max_iter=300, random_state=2021)
    k.fit(df_sd)
    dist.append(k.inertia_)

    

plt.plot(range(1,20), dist, marker='o')

# plt.vlines(3, ymin=dist.min()*0.999, ymax = dist.max()*1.0003, linestyles='--', colors='g')
# plt.vlines(4, ymin=dist.min()*0.999, ymax = dist.max()*1.0003, linestyles='--', colors='r')

plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %%
df_sd_arr = df_sd.values

kmeans = KMeans(n_clusters = 3,random_state=2021).fit(df_sd_arr)
kmeans.cluster_centers_
# Out:
# array([[-0.56242591,  0.11829875, -0.44444747, -0.58443908, -0.52101878,
#         -0.59583723, -0.55332724],
#        [ 0.26173002, -0.23007687,  0.23369601,  0.43144999,  0.33903191,
#          0.46821566,  0.31431545],
#        [ 2.21627317,  0.00543307,  1.67897677,  1.87331831,  1.79290049,
#          1.83346232,  2.02732209]])

# %%
df_sd['cluster'] = kmeans.labels_
df_sd
# Out:
#                    0         1         2         3         4         5  \
# S010000373 -0.915016 -0.135188 -0.513466 -0.999186 -0.800620 -0.848294
# S010000375  1.448221 -0.595401 -0.513466  1.972370  0.444270 -0.612247
# S010000376 -0.915016 -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# S000003540 -0.915016 -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# S010000581  0.266603 -0.135188  0.975740  0.486592  0.195292  1.040082
# ...              ...       ...       ...       ...       ...       ...
# S010000436 -0.206045  0.325025  1.472143 -0.404874 -0.302664 -0.376200
# S010000585 -0.442368 -0.595401 -0.513466 -0.404874  0.693248 -0.376200
# S010005523 -0.206045 -0.595401 -0.513466  0.189437  0.444270 -0.612247
# S010000592  5.938371  0.094919  1.472143  1.080903  0.942226  1.748223
# S010000557 -0.678692  0.555132 -0.513466 -0.702030 -0.800620 -0.848294
#
#                    6  cluster
# S010000373 -0.748290        0
# S010000375  2.402405        1
# S010000376 -0.748290        0
# S000003540 -0.748290        0
# S010000581  0.602008        1
# ...              ...      ...
# S010000436 -0.298191        0
# S010000585 -0.748290        0
# S010005523  0.151909        1
# S010000592  6.903397        2
# S010000557 -0.748290        0
#
# [320 rows x 8 columns]

# %%
from sklearn.manifold import TSNE

model = TSNE(learning_rate=100)
transformed = model.fit_transform(df_sd.iloc[:,:7])

xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=kmeans.labels_)

plt.show()

# %%
df_sd.reset_index(inplace=True)
df_sd.rename(columns={'index':'학교코드',0:'학교폭력유형_계',1:'200미터내_청소년출입금지업소개수',2:'개최횟수',3:'심의건수',4:'피해학생수',5:'가해학생수',6:'신체폭력'},inplace=True)

# %%
df_sd['cluster'].value_counts()
# Out:
# 0    187
# 1     97
# 2     36
# Name: cluster, dtype: int64

# %%
hazard = pd.merge(school_info, df_sd, on='학교코드', how='left')
# final.head()

# %%
hazard_score = hazard[['학교폭력유형_계','200미터내_청소년출입금지업소개수','개최횟수','심의건수','피해학생수','가해학생수','신체폭력','cluster']].groupby('cluster').mean()
# final_score = final.groupby('cluster').mean()
hazard_score
# Out:
#          학교폭력유형_계  200미터내_청소년출입금지업소개수      개최횟수      심의건수     피해학생수     가해학생수  \
# cluster
# 0       -0.562426            0.118299 -0.444447 -0.584439 -0.521019 -0.595837
# 1        0.261730           -0.230077  0.233696  0.431450  0.339032  0.468216
# 2        2.216273            0.005433  1.678977  1.873318  1.792900  1.833462
#
#              신체폭력
# cluster
# 0       -0.553327
# 1        0.314315
# 2        2.027322

# %%
tmp = hazard[hazard['cluster']==0]
tmp['지역'].nunique()
# Out:
# 25

# %% [markdown]
# ***
# ## 결과 해석
#
# * **cluster2 > cluster1 > cluster0**
#
# - cluster 0 : 학교폭력 발생 건수가 낮고, 200m 내 청소년 유해업소수가 많음
# - cluster 1 : 학교폭력 발생 건수가 약간 높음, 200m 내 청소년 유해업소수가 적음
# - cluster 2 : 학교폭력 발생 건수가 전체적으로 높음, 200m 내 청소년 유해업소수가 상대적으로 많음

# %% [markdown]
# ***
# ## 위해지표 점수 산출

# %% [markdown]
# ### 1차 점수

# %%
rank = hazard_score.sort_values('심의건수').index
rank
# Out:
# Int64Index([0, 1, 2], dtype='int64', name='cluster')

# %%
hazard['score_1st'] = ''

# %%
for i in range(len(hazard)):
    if hazard['cluster'][i]==rank[0]:
        hazard['score_1st'][i]=0.3
    elif hazard['cluster'][i]==rank[1]:
        hazard['score_1st'][i]=0.6
    elif hazard['cluster'][i]==rank[2]:
        hazard['score_1st'][i]=1

# %%
hazard
# Out:
#            학교코드               학교명   지역       법정동코드         위도          경도  \
# 0    S010000373            개포고등학교  강남구  1168010300  37.484959  127.059405
# 1    S010000375            경기고등학교  강남구  1168010500  37.517566  127.056074
# 2    S010000376          경기여자고등학교  강남구  1168010300  37.486887  127.065567
# 3    S000003540          국립국악고등학교  강남구  1168010300  37.476230  127.051476
# 4    S010000581  단국대학교부속소프트웨어고등학교  강남구  1168010600  37.495617  127.057767
# ..          ...               ...  ...         ...        ...         ...
# 315  S010000436          무학여자고등학교  성동구  1120010700  37.556768  127.033599
# 316  S010000585          서울방송고등학교  성동구  1120011300  37.547773  127.011036
# 317  S010005523            성수고등학교  성동구  1120011400  37.547342  127.038253
# 318  S010000592          성수공업고등학교  성동구  1120011500  37.540540  127.051298
# 319  S010000557   한양대학교사범대학부속고등학교  성동구  1120010600  37.561919  127.042326
#
#      학교폭력유형_계  200미터내_청소년출입금지업소개수      개최횟수      심의건수     피해학생수     가해학생수  \
# 0   -0.915016           -0.135188 -0.513466 -0.999186 -0.800620 -0.848294
# 1    1.448221           -0.595401 -0.513466  1.972370  0.444270 -0.612247
# 2   -0.915016           -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# 3   -0.915016           -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# 4    0.266603           -0.135188  0.975740  0.486592  0.195292  1.040082
# ..        ...                 ...       ...       ...       ...       ...
# 315 -0.206045            0.325025  1.472143 -0.404874 -0.302664 -0.376200
# 316 -0.442368           -0.595401 -0.513466 -0.404874  0.693248 -0.376200
# 317 -0.206045           -0.595401 -0.513466  0.189437  0.444270 -0.612247
# 318  5.938371            0.094919  1.472143  1.080903  0.942226  1.748223
# 319 -0.678692            0.555132 -0.513466 -0.702030 -0.800620 -0.848294
#
#          신체폭력  cluster score_1st
# 0   -0.748290        0       0.3
# 1    2.402405        1       0.6
# 2   -0.748290        0       0.3
# 3   -0.748290        0       0.3
# 4    0.602008        1       0.6
# ..        ...      ...       ...
# 315 -0.298191        0       0.3
# 316 -0.748290        0       0.3
# 317  0.151909        1       0.6
# 318  6.903397        2         1
# 319 -0.748290        0       0.3
#
# [320 rows x 15 columns]

# %% [markdown]
# ### 2차 점수

# %%
df = pd.read_csv(path+'청소년인구밀도_구.csv', encoding = 'cp949')
df['청소년인구밀도'] = df['청소년(15-19세)']/df['면적(㎢)']
df.rename(columns={'구':'지역'},inplace=True)

people_density = df[['지역','청소년인구밀도']]
people_density
# Out:
#       지역      청소년인구밀도
# 0    종로구   275.826014
# 1     중구   417.068273
# 2    용산구   415.363512
# 3    성동구   703.380783
# 4    광진구   893.728019
# 5   동대문구   985.654008
# 6    중랑구   864.918919
# 7    성북구   876.434676
# 8    강북구   566.355932
# 9    도봉구   763.891578
# 10   노원구   909.593679
# 11   은평구   759.912487
# 12  서대문구   783.267158
# 13   마포구   663.731656
# 14   양천구  1619.356692
# 15   강서구   623.214286
# 16   구로구   840.109344
# 17   금천구   687.480799
# 18  영등포구   556.700611
# 19   동작구   989.908257
# 20   관악구   589.212039
# 21   서초구   502.852278
# 22   강남구   819.949367
# 23   송파구   973.250664
# 24   강동구   845.872306

# %%
hazard_2nd = pd.merge(hazard,people_density,how='left',on='지역')
hazard_2nd
# Out:
#            학교코드               학교명   지역       법정동코드         위도          경도  \
# 0    S010000373            개포고등학교  강남구  1168010300  37.484959  127.059405
# 1    S010000375            경기고등학교  강남구  1168010500  37.517566  127.056074
# 2    S010000376          경기여자고등학교  강남구  1168010300  37.486887  127.065567
# 3    S000003540          국립국악고등학교  강남구  1168010300  37.476230  127.051476
# 4    S010000581  단국대학교부속소프트웨어고등학교  강남구  1168010600  37.495617  127.057767
# ..          ...               ...  ...         ...        ...         ...
# 315  S010000436          무학여자고등학교  성동구  1120010700  37.556768  127.033599
# 316  S010000585          서울방송고등학교  성동구  1120011300  37.547773  127.011036
# 317  S010005523            성수고등학교  성동구  1120011400  37.547342  127.038253
# 318  S010000592          성수공업고등학교  성동구  1120011500  37.540540  127.051298
# 319  S010000557   한양대학교사범대학부속고등학교  성동구  1120010600  37.561919  127.042326
#
#      학교폭력유형_계  200미터내_청소년출입금지업소개수      개최횟수      심의건수     피해학생수     가해학생수  \
# 0   -0.915016           -0.135188 -0.513466 -0.999186 -0.800620 -0.848294
# 1    1.448221           -0.595401 -0.513466  1.972370  0.444270 -0.612247
# 2   -0.915016           -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# 3   -0.915016           -0.595401 -0.513466 -0.999186 -0.800620 -0.848294
# 4    0.266603           -0.135188  0.975740  0.486592  0.195292  1.040082
# ..        ...                 ...       ...       ...       ...       ...
# 315 -0.206045            0.325025  1.472143 -0.404874 -0.302664 -0.376200
# 316 -0.442368           -0.595401 -0.513466 -0.404874  0.693248 -0.376200
# 317 -0.206045           -0.595401 -0.513466  0.189437  0.444270 -0.612247
# 318  5.938371            0.094919  1.472143  1.080903  0.942226  1.748223
# 319 -0.678692            0.555132 -0.513466 -0.702030 -0.800620 -0.848294
#
#          신체폭력  cluster score_1st     청소년인구밀도
# 0   -0.748290        0       0.3  819.949367
# 1    2.402405        1       0.6  819.949367
# 2   -0.748290        0       0.3  819.949367
# 3   -0.748290        0       0.3  819.949367
# 4    0.602008        1       0.6  819.949367
# ..        ...      ...       ...         ...
# 315 -0.298191        0       0.3  703.380783
# 316 -0.748290        0       0.3  703.380783
# 317  0.151909        1       0.6  703.380783
# 318  6.903397        2         1  703.380783
# 319 -0.748290        0       0.3  703.380783
#
# [320 rows x 16 columns]

# %%
hazard_2nd['score_2nd']=''

# %%
for i in range(len(hazard_2nd)):
    for k in range(4):
        rank_lis = sorted(list(set(hazard_2nd[hazard_2nd['cluster']==k]['청소년인구밀도'])), reverse=True) #한 군집내의 모든 인구밀도 내림차순 정렬
        for j in range(len(rank_lis)): #내림차순 정렬한 리스트의 인덱스 순서대로 적은 점수를 차감
            if hazard_2nd['청소년인구밀도'][i] == rank_lis[j]:
                hazard_2nd['score_2nd'][i] = round((hazard_2nd['score_1st'][i]-(j/len(rank_lis))*0.2)*10,2) # 점수 만점을 10점으로 만들기

# %%
hazard_fin = hazard_2nd[['학교코드','학교명','지역','위도','경도','score_2nd']]
hazard_fin.sort_values(by=['score_2nd'], ascending=[False]).head(30)
# Out:
#            학교코드           학교명    지역         위도          경도 score_2nd
# 151  S010000642      서울금융고등학교   양천구  37.537615  126.825664     10.00
# 145  S010000396        광영고등학교   양천구  37.537197  126.823275     10.00
# 279  S010000588      서울공업고등학교   동작구  37.501902  126.922364      9.88
# 276  S010005573        휘봉고등학교  동대문구  37.586508  127.068997      9.76
# 274  S010000602      휘경공업고등학교  동대문구  37.585220  127.069729      9.76
# 133  S010000593      송파공업고등학교   송파구  37.491476  127.142528      9.65
# 128  S010005182        방산고등학교   송파구  37.508400  127.120472      9.65
# 244  S010000494        염광고등학교   노원구  37.628422  127.049528      9.53
# 246  S010000619  영신간호비즈니스고등학교   노원구  37.652454  127.083277      9.53
# 237  S010005263        불암고등학교   노원구  37.649158  127.080304      9.53
# 241  S010000651      서울동산고등학교   노원구  37.630202  127.075060      9.53
# 232  S010000580    광운전자공업고등학교   노원구  37.619241  127.056544      9.53
# 115  S010000629      고명외식고등학교   성북구  37.597320  127.020190      9.41
# 113  S010000386        계성고등학교   성북구  37.607710  127.020310      9.41
# 226  S010005364        원묵고등학교   중랑구  37.615506  127.086204      9.29
# 95   S010000399        구일고등학교   구로구  37.494410  126.873942      9.18
# 92   S010000383        경인고등학교   구로구  37.495994  126.865431      9.18
# 18   S010000542        청담고등학교   강남구  37.528001  127.043701      9.06
# 21   S010000568        휘문고등학교   강남구  37.505109  127.061420      9.06
# 188  S010000595    신진과학기술고등학교   은평구  37.598713  126.918835      8.94
# 185  S010000659     세명컴퓨터고등학교   은평구  37.627771  126.923249      8.94
# 193  S010005525        진관고등학교   은평구  37.643662  126.924272      8.94
# 183  S010000467        선정고등학교   은평구  37.618704  126.909031      8.94
# 318  S010000592      성수공업고등학교   성동구  37.540540  127.051298      8.82
# 106  S000005401    국립전통예술고등학교   금천구  37.446354  126.906414      8.71
# 46   S010000389        공항고등학교   강서구  37.570122  126.818420      8.59
# 43   S010000578      강서공업고등학교   강서구  37.576034  126.816183      8.59
# 82   S010000519        인헌고등학교   관악구  37.472309  126.970485      8.47
# 79   S010000484        신림고등학교   관악구  37.478383  126.916640      8.47
# 81   S010000611    영락의료과학고등학교   관악구  37.476564  126.944783      8.47
