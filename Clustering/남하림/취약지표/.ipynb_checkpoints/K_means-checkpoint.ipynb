# %%
import pandas as pd
import warnings 
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon, LineString, Point
warnings.filterwarnings(action='ignore')

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist
from sklearn.preprocessing import StandardScaler

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# # 1. 결측치 확인

# %%
data = pd.read_csv('data/new_data5.csv')
data
# Out:
#                  학교명   학급수     학생수   학급당평균학생수    교원수   자치구  전입학생수  전출학생수  \
# 0           국립국악고등학교  15.0   442.0  29.466667   47.0   강남구    0.0    5.0
# 1             개포고등학교  30.0   643.0  21.433333   72.0   강남구   10.0   11.0
# 2             경기고등학교  45.0  1214.0  26.977778  101.0   강남구   36.0   27.0
# 3           경기여자고등학교  43.0  1141.0  26.534884   98.0   강남구   21.0   18.0
# 4           서울로봇고등학교  24.0   460.0  19.166667   76.0   강남구    0.0    5.0
# ..               ...   ...     ...        ...    ...   ...    ...    ...
# 315  동국대학교사범대학부속고등학교  33.0   949.0  28.757576   73.0  동대문구   33.0   20.0
# 316       정화여자상업고등학교  19.0   334.0  17.578947   43.0  동대문구    5.0    7.0
# 317      해성국제컨벤션고등학교  27.0   635.0  23.518519   61.0  동대문구    4.0   18.0
# 318         해성여자고등학교  27.0   673.0  24.925926   58.0  동대문구   16.0    6.0
# 319         휘경여자고등학교  33.0   851.0  25.787879   71.0  동대문구   13.0   23.0
#
#      주거환경  경제환경  사회환경  교육환경       청소년유동인구  한부모_가구수  한부모_가구원수   저소득    중간  \
# 0    6.44  5.38  6.27  5.84  45613.514389      973      2294  20.4  44.9
# 1    6.44  5.38  6.27  5.84  45613.514389      973      2294  20.4  44.9
# 2    6.44  5.38  6.27  5.84  45613.514389      973      2294  20.4  44.9
# 3    6.44  5.38  6.27  5.84  45613.514389      973      2294  20.4  44.9
# 4    6.44  5.38  6.27  5.84  45613.514389      973      2294  20.4  44.9
# ..    ...   ...   ...   ...           ...      ...       ...   ...   ...
# 315  6.10  5.16  5.86  5.55  18514.572581     1157      2709  31.6  46.3
# 316  6.10  5.16  5.86  5.55  18514.572581     1157      2709  31.6  46.3
# 317  6.10  5.16  5.86  5.55  18514.572581     1157      2709  31.6  46.3
# 318  6.10  5.16  5.86  5.55  18514.572581     1157      2709  31.6  46.3
# 319  6.10  5.16  5.86  5.55  18514.572581     1157      2709  31.6  46.3
#
#       고소득  학업중단율
# 0    34.7    0.5
# 1    34.7    1.9
# 2    34.7    1.8
# 3    34.7    2.3
# 4    34.7    0.2
# ..    ...    ...
# 315  22.0    1.1
# 316  22.0    3.6
# 317  22.0    2.0
# 318  22.0    1.2
# 319  22.0    1.6
#
# [320 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# 학교명         0
# 학급수         0
# 학생수         0
# 학급당평균학생수    0
# 교원수         0
# 자치구         0
# 전입학생수       0
# 전출학생수       0
# 주거환경        0
# 경제환경        0
# 사회환경        0
# 교육환경        0
# 청소년유동인구     0
# 한부모_가구수     0
# 한부모_가구원수    0
# 저소득         0
# 중간          0
# 고소득         0
# 학업중단율       0
# dtype: int64

# %%
data.corr()
# Out:
#                학급수       학생수  학급당평균학생수       교원수     전입학생수     전출학생수  \
# 학급수       1.000000  0.890171  0.301643  0.915582  0.323179  0.304797
# 학생수       0.890171  1.000000  0.684922  0.762437  0.421432  0.339231
# 학급당평균학생수  0.301643  0.684922  1.000000  0.177810  0.335132  0.226999
# 교원수       0.915582  0.762437  0.177810  1.000000  0.229935  0.264934
# 전입학생수     0.323179  0.421432  0.335132  0.229935  1.000000  0.388842
# 전출학생수     0.304797  0.339231  0.226999  0.264934  0.388842  1.000000
# 주거환경      0.119444  0.096983  0.026629  0.129266  0.002536 -0.059664
# 경제환경      0.060082  0.064187  0.042779  0.047064 -0.011465 -0.068186
# 사회환경      0.194025  0.171141  0.055719  0.183701  0.075024 -0.014089
# 교육환경      0.200755  0.161461  0.033539  0.205886  0.117735  0.061539
# 청소년유동인구   0.266669  0.247609  0.108137  0.269401  0.111875  0.024953
# 한부모_가구수   0.100533  0.069096  0.018892  0.050010 -0.069272 -0.106495
# 한부모_가구원수  0.103947  0.072611  0.020728  0.051099 -0.066703 -0.104603
# 저소득       0.113686  0.090125  0.023744  0.107620 -0.056105 -0.024722
# 중간        0.033603  0.023178  0.026915 -0.042978 -0.047625 -0.051875
# 고소득      -0.114809 -0.088281 -0.040345 -0.047371  0.081513  0.061121
# 학업중단율    -0.280915 -0.341874 -0.335239 -0.255171  0.022028  0.001529
#
#               주거환경      경제환경      사회환경      교육환경   청소년유동인구   한부모_가구수  \
# 학급수       0.119444  0.060082  0.194025  0.200755  0.266669  0.100533
# 학생수       0.096983  0.064187  0.171141  0.161461  0.247609  0.069096
# 학급당평균학생수  0.026629  0.042779  0.055719  0.033539  0.108137  0.018892
# 교원수       0.129266  0.047064  0.183701  0.205886  0.269401  0.050010
# 전입학생수     0.002536 -0.011465  0.075024  0.117735  0.111875 -0.069272
# 전출학생수    -0.059664 -0.068186 -0.014089  0.061539  0.024953 -0.106495
# 주거환경      1.000000  0.544610  0.610195  0.371303  0.323578  0.119865
# 경제환경      0.544610  1.000000  0.263616  0.217567  0.067397  0.035820
# 사회환경      0.610195  0.263616  1.000000  0.598433  0.628808  0.004548
# 교육환경      0.371303  0.217567  0.598433  1.000000  0.401710 -0.344770
# 청소년유동인구   0.323578  0.067397  0.628808  0.401710  1.000000  0.335605
# 한부모_가구수   0.119865  0.035820  0.004548 -0.344770  0.335605  1.000000
# 한부모_가구원수  0.117175  0.038311  0.014190 -0.337436  0.343126  0.999023
# 저소득      -0.059682  0.240622  0.049228 -0.110109  0.092112  0.296411
# 중간        0.094830 -0.087466 -0.053832  0.003532  0.070021  0.473565
# 고소득      -0.031316 -0.111907  0.006616  0.081985 -0.127965 -0.615310
# 학업중단율     0.002619 -0.042984 -0.010036  0.011802 -0.010441 -0.056880
#
#           한부모_가구원수       저소득        중간       고소득     학업중단율
# 학급수       0.103947  0.113686  0.033603 -0.114809 -0.280915
# 학생수       0.072611  0.090125  0.023178 -0.088281 -0.341874
# 학급당평균학생수  0.020728  0.023744  0.026915 -0.040345 -0.335239
# 교원수       0.051099  0.107620 -0.042978 -0.047371 -0.255171
# 전입학생수    -0.066703 -0.056105 -0.047625  0.081513  0.022028
# 전출학생수    -0.104603 -0.024722 -0.051875  0.061121  0.001529
# 주거환경      0.117175 -0.059682  0.094830 -0.031316  0.002619
# 경제환경      0.038311  0.240622 -0.087466 -0.111907 -0.042984
# 사회환경      0.014190  0.049228 -0.053832  0.006616 -0.010036
# 교육환경     -0.337436 -0.110109  0.003532  0.081985  0.011802
# 청소년유동인구   0.343126  0.092112  0.070021 -0.127965 -0.010441
# 한부모_가구수   0.999023  0.296411  0.473565 -0.615310 -0.056880
# 한부모_가구원수  1.000000  0.277002  0.492917 -0.616300 -0.058813
# 저소득       0.277002  1.000000 -0.206706 -0.597452 -0.020323
# 중간        0.492917 -0.206706  1.000000 -0.661074 -0.019859
# 고소득      -0.616300 -0.597452 -0.661074  1.000000  0.031774
# 학업중단율    -0.058813 -0.020323 -0.019859  0.031774  1.000000

# %% [markdown]
# # 2. K-means 모델링

# %% [markdown]
# data파일을 복사하기

# %%
df = data.copy()

# %%
labels= np.array(df['학교명'])

# %%
school_info = df[['학교명','자치구']]

# %%
total=df.loc[:,['학급수','학생수','학급당평균학생수','전출학생수','경제환경','교육환경','저소득','학업중단율']]
total
# Out:
#       학급수     학생수   학급당평균학생수  전출학생수  경제환경  교육환경   저소득  학업중단율
# 0    15.0   442.0  29.466667    5.0  5.38  5.84  20.4    0.5
# 1    30.0   643.0  21.433333   11.0  5.38  5.84  20.4    1.9
# 2    45.0  1214.0  26.977778   27.0  5.38  5.84  20.4    1.8
# 3    43.0  1141.0  26.534884   18.0  5.38  5.84  20.4    2.3
# 4    24.0   460.0  19.166667    5.0  5.38  5.84  20.4    0.2
# ..    ...     ...        ...    ...   ...   ...   ...    ...
# 315  33.0   949.0  28.757576   20.0  5.16  5.55  31.6    1.1
# 316  19.0   334.0  17.578947    7.0  5.16  5.55  31.6    3.6
# 317  27.0   635.0  23.518519   18.0  5.16  5.55  31.6    2.0
# 318  27.0   673.0  24.925926    6.0  5.16  5.55  31.6    1.2
# 319  33.0   851.0  25.787879   23.0  5.16  5.55  31.6    1.6
#
# [320 rows x 8 columns]

# %% [markdown]
# ## 데이터 표준화

# %%
sd = StandardScaler()
total_sd=pd.DataFrame(sd.fit_transform(total))
total_sd.index = labels

# %%
total_sd.head()
# Out:
#                  0         1         2         3         4       5         6  \
# 국립국악고등학교 -1.938249 -1.161039  1.105093 -1.001236  0.147603  1.1236 -0.236796
# 개포고등학교    0.054382 -0.375079 -0.732681 -0.486682  0.147603  1.1236 -0.236796
# 경기고등학교    2.047014  1.857675  0.535713  0.885461  0.147603  1.1236 -0.236796
# 경기여자고등학교  1.781329  1.572227  0.434393  0.113631  0.147603  1.1236 -0.236796
# 서울로봇고등학교 -0.742670 -1.090655 -1.251224 -1.001236  0.147603  1.1236 -0.236796
#
#                  7
# 국립국악고등학교 -0.861804
# 개포고등학교   -0.080091
# 경기고등학교   -0.135927
# 경기여자고등학교  0.143256
# 서울로봇고등학교 -1.029314

# %%
dist =[]
for i in range(1,20):
    k = KMeans(n_clusters=i,
          init='k-means++',
           n_init=10,
           max_iter=300,
           random_state=0)
    k.fit(total_sd)
    dist.append(k.inertia_)

plt.plot(range(1,20),dist, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %% [markdown]
# k = 3으로 지정

# %% [markdown]
# ## 군집화

# %%
np.random.seed(1234)

# %%
total_sd_arr = total_sd.values

#k값을 3로 설정 후 k-means에 적용시키기
kmeans = KMeans(n_clusters =3,random_state=2021).fit(total_sd_arr)
kmeans.cluster_centers_
# Out:
# array([[-1.19554109, -1.42213761, -1.45278989, -0.22160892, -0.32288726,
#         -0.26267482, -0.30691768,  2.8894054 ],
#        [-0.4472237 , -0.50702302, -0.28801979, -0.36390146,  0.02537756,
#         -0.09383607, -0.05682974, -0.21708893],
#        [ 0.94038123,  1.07888904,  0.73625217,  0.62147273,  0.02138631,
#          0.19957259,  0.1491481 , -0.20730126]])

# %%
total_sd['cluster'] = kmeans.labels_
total_sd
# Out:
#                         0         1         2         3         4         5  \
# 국립국악고등학교        -1.938249 -1.161039  1.105093 -1.001236  0.147603  1.123600
# 개포고등학교           0.054382 -0.375079 -0.732681 -0.486682  0.147603  1.123600
# 경기고등학교           2.047014  1.857675  0.535713  0.885461  0.147603  1.123600
# 경기여자고등학교         1.781329  1.572227  0.434393  0.113631  0.147603  1.123600
# 서울로봇고등학교        -0.742670 -1.090655 -1.251224 -1.001236  0.147603  1.123600
# ...                   ...       ...       ...       ...       ...       ...
# 동국대학교사범대학부속고등학교  0.452909  0.821458  0.942875  0.285149 -1.161117 -1.017909
# 정화여자상업고등학교      -1.406881 -1.583347 -1.614444 -0.829718 -1.161117 -1.017909
# 해성국제컨벤션고등학교     -0.344144 -0.406361 -0.255657  0.113631 -1.161117 -1.017909
# 해성여자고등학교        -0.344144 -0.257771  0.066314 -0.915477 -1.161117 -1.017909
# 휘경여자고등학교         0.452909  0.438254  0.263502  0.542425 -1.161117 -1.017909
#
#                         6         7  cluster
# 국립국악고등학교        -0.236796 -0.861804        1
# 개포고등학교          -0.236796 -0.080091        1
# 경기고등학교          -0.236796 -0.135927        2
# 경기여자고등학교        -0.236796  0.143256        2
# 서울로봇고등학교        -0.236796 -1.029314        1
# ...                   ...       ...      ...
# 동국대학교사범대학부속고등학교  1.348333 -0.526784        2
# 정화여자상업고등학교       1.348333  0.869133        0
# 해성국제컨벤션고등학교      1.348333 -0.024254        1
# 해성여자고등학교         1.348333 -0.470947        1
# 휘경여자고등학교         1.348333 -0.247601        2
#
# [320 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

model = TSNE(learning_rate=100)
transformed = model.fit_transform(total_sd.iloc[:,:8])

xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=kmeans.labels_)

plt.show()

#군집별로 잘 구분이 된 것을 알 수 있다.

# %%
total_sd.reset_index(inplace=True)

total_sd.rename(columns={'index':'학교명',0:'학급수',1:'학생수',2:'학급당평균학생수',3:'전출학생수',4:'경제환경',5:'교육환경',6:'저소득',7:'학업중단율'},inplace=True)

# %%
total_sd
# Out:
#                  학교명       학급수       학생수  학급당평균학생수     전출학생수      경제환경  \
# 0           국립국악고등학교 -1.938249 -1.161039  1.105093 -1.001236  0.147603
# 1             개포고등학교  0.054382 -0.375079 -0.732681 -0.486682  0.147603
# 2             경기고등학교  2.047014  1.857675  0.535713  0.885461  0.147603
# 3           경기여자고등학교  1.781329  1.572227  0.434393  0.113631  0.147603
# 4           서울로봇고등학교 -0.742670 -1.090655 -1.251224 -1.001236  0.147603
# ..               ...       ...       ...       ...       ...       ...
# 315  동국대학교사범대학부속고등학교  0.452909  0.821458  0.942875  0.285149 -1.161117
# 316       정화여자상업고등학교 -1.406881 -1.583347 -1.614444 -0.829718 -1.161117
# 317      해성국제컨벤션고등학교 -0.344144 -0.406361 -0.255657  0.113631 -1.161117
# 318         해성여자고등학교 -0.344144 -0.257771  0.066314 -0.915477 -1.161117
# 319         휘경여자고등학교  0.452909  0.438254  0.263502  0.542425 -1.161117
#
#          교육환경       저소득     학업중단율  cluster
# 0    1.123600 -0.236796 -0.861804        1
# 1    1.123600 -0.236796 -0.080091        1
# 2    1.123600 -0.236796 -0.135927        2
# 3    1.123600 -0.236796  0.143256        2
# 4    1.123600 -0.236796 -1.029314        1
# ..        ...       ...       ...      ...
# 315 -1.017909  1.348333 -0.526784        2
# 316 -1.017909  1.348333  0.869133        0
# 317 -1.017909  1.348333 -0.024254        1
# 318 -1.017909  1.348333 -0.470947        1
# 319 -1.017909  1.348333 -0.247601        2
#
# [320 rows x 10 columns]

# %%
total_sd['cluster'].value_counts()
# Out:
# 1    183
# 2    115
# 0     22
# Name: cluster, dtype: int64

# %%
final = pd.merge(total_sd,school_info,on='학교명',how='left')
final.head()
# Out:
#         학교명       학급수       학생수  학급당평균학생수     전출학생수      경제환경    교육환경  \
# 0  국립국악고등학교 -1.938249 -1.161039  1.105093 -1.001236  0.147603  1.1236
# 1    개포고등학교  0.054382 -0.375079 -0.732681 -0.486682  0.147603  1.1236
# 2    경기고등학교  2.047014  1.857675  0.535713  0.885461  0.147603  1.1236
# 3  경기여자고등학교  1.781329  1.572227  0.434393  0.113631  0.147603  1.1236
# 4  서울로봇고등학교 -0.742670 -1.090655 -1.251224 -1.001236  0.147603  1.1236
#
#         저소득     학업중단율  cluster  자치구
# 0 -0.236796 -0.861804        1  강남구
# 1 -0.236796 -0.080091        1  강남구
# 2 -0.236796 -0.135927        2  강남구
# 3 -0.236796  0.143256        2  강남구
# 4 -0.236796 -1.029314        1  강남구

# %%
final.groupby('cluster').mean()
# Out:
#               학급수       학생수  학급당평균학생수     전출학생수      경제환경      교육환경       저소득  \
# cluster
# 0       -1.195541 -1.422138 -1.452790 -0.221609 -0.322887 -0.262675 -0.306918
# 1       -0.446109 -0.509232 -0.294815 -0.353176  0.027342 -0.078280 -0.064283
# 2        0.938861  1.087590  0.751704  0.630383  0.023544  0.215368  0.142551
#
#             학업중단율
# cluster
# 0        2.889405
# 1       -0.216212
# 2       -0.205127

# %%
final[final['cluster']==0].groupby('자치구').sum()
# Out:
#            학급수       학생수  학급당평균학생수     전출학생수      경제환경      교육환경       저소득  \
# 자치구
# 강남구  -1.938249 -1.966551 -2.036662  0.199390  0.147603  1.123600 -0.236796
# 강서구  -2.892221 -3.553503 -3.837888  1.541517 -4.018735 -1.059909 -0.837765
# 관악구  -3.345130 -3.217527 -2.472262 -1.830954 -1.370437 -0.854296 -0.020699
# 구로구  -3.876498 -3.248809 -1.282348 -2.088230  2.198797  0.474917  0.092525
# 도봉구  -0.953972 -2.310348 -3.742563  0.999092  0.176231 -2.035819 -2.285168
# 동대문구 -1.485341 -2.900796 -4.079193 -0.630328 -2.322233 -2.035819  2.696665
# 서초구  -1.406881 -1.493411 -1.337513 -0.315164 -0.685219  1.418981 -1.439796
# 성동구  -0.875512 -1.434757 -1.935872  0.542425 -1.577527 -0.427148 -0.350020
# 성북구  -1.539723 -1.626359 -1.530830 -1.430030 -0.744706 -0.648684 -1.453949
# 양천구  -0.609828 -1.602898 -2.625360 -0.658200  0.682988  0.237458  0.230251
# 용산구  -2.548077 -2.814771 -2.569171  0.227261 -0.180692  1.213368  0.573725
# 은평구  -1.618183 -1.629964 -0.960746 -0.801846  2.555720 -2.921961  0.177442
# 종로구  -3.212288 -3.487334 -3.550970 -0.630328 -1.965310 -0.263535 -3.898603
#
#          학업중단율  cluster
# 자치구
# 강남구   2.432560        0
# 강서구   8.526086        0
# 관악구   8.550341        0
# 구로구   8.550341        0
# 도봉구   3.245856        0
# 동대문구  4.195080        0
# 서초구   3.549293        0
# 성동구   6.229454        0
# 성북구   3.325947        0
# 양천구   3.102600        0
# 용산구   3.022509        0
# 은평구   4.865120        0
# 종로구   3.971733        0

# %%
final.to_csv('data/Vulnerability_Cluster.csv',index=False)
