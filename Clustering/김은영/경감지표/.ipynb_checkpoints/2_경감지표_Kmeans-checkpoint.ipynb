# %% [markdown]
# # K-means Clustering

# %%
import pandas as pd
import warnings 
# import geopandas as gpd
import numpy as np
# from shapely.geometry import Polygon, LineString, Point
warnings.filterwarnings(action='ignore')

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
from sklearn.preprocessing import StandardScaler

plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df=pd.read_csv('경감지수_전처리2.csv', encoding='utf-8', index_col=0)
labels= np.array(df['학교명'])
df
# Out:
#                   학교명        학교코드  내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  \
# 구
# 강남구            개포고등학교  S010000373          1          1            1
# 강남구            경기고등학교  S010000375          1          0            1
# 강남구          경기여자고등학교  S010000376          1          1            1
# 강남구          국립국악고등학교  S000003540          0          0            0
# 강남구  단국대학교부속소프트웨어고등학교  S010000581          0          1            0
# ..                ...         ...        ...        ...          ...
# 성동구          무학여자고등학교  S010000436          1          1            1
# 성동구          서울방송고등학교  S010000585          1          1            1
# 성동구            성수고등학교  S010005523          1          1            1
# 성동구          성수공업고등학교  S010000592          1          0            1
# 성동구   한양대학교사범대학부속고등학교  S010000557          1          1            1
#
#      학교폭력_예방교육_평균교육시간(1학급당)         위도          경도       법정동코드  500미터내_파출소개수  \
# 구
# 강남구                   382.4  37.484959  127.059405  1168010300             0
# 강남구                   152.4  37.517566  127.056074  1168010500             1
# 강남구                   200.0  37.486887  127.065567  1168010300             0
# 강남구                   217.4  37.476230  127.051476  1168010300             1
# 강남구                   300.0  37.495617  127.057767  1168010600             0
# ..                      ...        ...         ...         ...           ...
# 성동구                   253.3  37.556768  127.033599  1120010700             1
# 성동구                    87.6  37.547773  127.011036  1120011300             1
# 성동구                   406.6  37.547342  127.038253  1120011400             0
# 성동구                   306.5  37.540540  127.051298  1120011500             1
# 성동구                   137.0  37.561919  127.042326  1120010600             1
#
#      방범용CCTV  어린이보호구역CCTV
# 구
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# ..       ...          ...
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
#
# [293 rows x 12 columns]

# %%
school_info = df[['학교명','학교코드']]
school_info
# Out:
#                   학교명        학교코드
# 구
# 강남구            개포고등학교  S010000373
# 강남구            경기고등학교  S010000375
# 강남구          경기여자고등학교  S010000376
# 강남구          국립국악고등학교  S000003540
# 강남구  단국대학교부속소프트웨어고등학교  S010000581
# ..                ...         ...
# 성동구          무학여자고등학교  S010000436
# 성동구          서울방송고등학교  S010000585
# 성동구            성수고등학교  S010005523
# 성동구          성수공업고등학교  S010000592
# 성동구   한양대학교사범대학부속고등학교  S010000557
#
# [293 rows x 2 columns]

# %%
total=df.loc[:,['내부상담_실시여부','외부상담_실시여부','wee클래스_운영여부','학교폭력_예방교육_평균교육시간(1학급당)','500미터내_파출소개수','방범용CCTV','어린이보호구역CCTV']]
total
# Out:
#      내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  학교폭력_예방교육_평균교육시간(1학급당)  500미터내_파출소개수  \
# 구
# 강남구          1          1            1                   382.4             0
# 강남구          1          0            1                   152.4             1
# 강남구          1          1            1                   200.0             0
# 강남구          0          0            0                   217.4             1
# 강남구          0          1            0                   300.0             0
# ..         ...        ...          ...                     ...           ...
# 성동구          1          1            1                   253.3             1
# 성동구          1          1            1                    87.6             1
# 성동구          1          1            1                   406.6             0
# 성동구          1          0            1                   306.5             1
# 성동구          1          1            1                   137.0             1
#
#      방범용CCTV  어린이보호구역CCTV
# 구
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# 강남구     4525          775
# ..       ...          ...
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
# 성동구     2834            0
#
# [293 rows x 7 columns]

# %% [markdown]
# ## 표준화

# %%
sd = StandardScaler()
total_sd=pd.DataFrame(sd.fit_transform(total))
total_sd.index = labels
total_sd.head()
# Out:
#                          0         1         2         3         4         5  \
# 개포고등학교            0.409061  0.576037  0.549747  0.014073 -0.844731  2.656181
# 경기고등학교            0.409061 -1.736001  0.549747 -0.767403  0.569590  2.656181
# 경기여자고등학교          0.409061  0.576037  0.549747 -0.605672 -0.844731  2.656181
# 국립국악고등학교         -2.444625 -1.736001 -1.819017 -0.546551  0.569590  2.656181
# 단국대학교부속소프트웨어고등학교 -2.444625  0.576037 -1.819017 -0.265899 -0.844731  2.656181
#
#                          6
# 개포고등학교            1.887308
# 경기고등학교            1.887308
# 경기여자고등학교          1.887308
# 국립국악고등학교          1.887308
# 단국대학교부속소프트웨어고등학교  1.887308

# %% [markdown]
# ## 최적 K 개수 산출

# %%
dist =[]
for i in range(1,20):
    k = KMeans(n_clusters=i,
          init='k-means++',
           n_init=10,
           max_iter=300,
           random_state=0)
    k.fit(total_sd)
    dist.append(k.inertia_)

plt.plot(range(1,20),dist, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
plt.show()

# %%
np.random.seed(123)
total_sd_arr = total_sd.values

# k값을 5로 설정 후 k-means에 적용시키기
kmeans = KMeans(n_clusters=5, random_state=2021).fit(total_sd_arr)
kmeans.cluster_centers_
# Out:
# array([[ 0.40906073,  0.57603661,  0.52120808, -0.42245652, -0.45281058,
#         -0.31464852, -0.50483392],
#        [-2.44462481, -0.34877833, -1.16760692, -0.12651604,  0.03921964,
#          0.22516444,  0.31507898],
#        [ 0.40906073, -1.73600076,  0.0388374 , -0.08488709, -0.04050922,
#         -0.29064038, -0.23267369],
#        [ 0.40906073,  0.53813436, -0.03273568,  0.78306193,  0.98693041,
#         -0.51848169, -0.61961797],
#        [ 0.31065778,  0.37672305,  0.05965819, -0.05712074, -0.38141883,
#          1.09584988,  1.36139846]])

# %% [markdown]
# ## 군집화

# %%
total_sd['cluster'] = kmeans.labels_
total_sd
# Out:
#                          0         1         2         3         4         5  \
# 개포고등학교            0.409061  0.576037  0.549747  0.014073 -0.844731  2.656181
# 경기고등학교            0.409061 -1.736001  0.549747 -0.767403  0.569590  2.656181
# 경기여자고등학교          0.409061  0.576037  0.549747 -0.605672 -0.844731  2.656181
# 국립국악고등학교         -2.444625 -1.736001 -1.819017 -0.546551  0.569590  2.656181
# 단국대학교부속소프트웨어고등학교 -2.444625  0.576037 -1.819017 -0.265899 -0.844731  2.656181
# ...                    ...       ...       ...       ...       ...       ...
# 무학여자고등학교          0.409061  0.576037  0.549747 -0.424573  0.569590  0.751136
# 서울방송고등학교          0.409061  0.576037  0.549747 -0.987576  0.569590  0.751136
# 성수고등학교            0.409061  0.576037  0.549747  0.096298 -0.844731  0.751136
# 성수공업고등학교          0.409061 -1.736001  0.549747 -0.243814  0.569590  0.751136
# 한양대학교사범대학부속고등학교   0.409061  0.576037  0.549747 -0.819728  0.569590  0.751136
#
#                          6  cluster
# 개포고등학교            1.887308        4
# 경기고등학교            1.887308        4
# 경기여자고등학교          1.887308        4
# 국립국악고등학교          1.887308        1
# 단국대학교부속소프트웨어고등학교  1.887308        1
# ...                    ...      ...
# 무학여자고등학교         -1.555691        0
# 서울방송고등학교         -1.555691        0
# 성수고등학교           -1.555691        0
# 성수공업고등학교         -1.555691        2
# 한양대학교사범대학부속고등학교  -1.555691        0
#
# [293 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

model = TSNE(learning_rate=100)
transformed = model.fit_transform(total_sd.iloc[:,:7])

xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=kmeans.labels_)

plt.show()

# %%
total_sd.reset_index(inplace=True)
total_sd.rename(columns={'index': '학교명', 0: '내부상담_실시여부', 1: '외부상담_실시여부', 2: 'wee클래스_운영여부',
                         3: '학교폭력_예방교육_평균교육시간(1학급당)', 4: '500미터내_파출소개수', 5: '방범용CCTV', 6: '어린이보호구역CCTV'}, inplace=True)
total_sd
# Out:
#                   학교명  내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  \
# 0              개포고등학교   0.409061   0.576037     0.549747
# 1              경기고등학교   0.409061  -1.736001     0.549747
# 2            경기여자고등학교   0.409061   0.576037     0.549747
# 3            국립국악고등학교  -2.444625  -1.736001    -1.819017
# 4    단국대학교부속소프트웨어고등학교  -2.444625   0.576037    -1.819017
# ..                ...        ...        ...          ...
# 288          무학여자고등학교   0.409061   0.576037     0.549747
# 289          서울방송고등학교   0.409061   0.576037     0.549747
# 290            성수고등학교   0.409061   0.576037     0.549747
# 291          성수공업고등학교   0.409061  -1.736001     0.549747
# 292   한양대학교사범대학부속고등학교   0.409061   0.576037     0.549747
#
#      학교폭력_예방교육_평균교육시간(1학급당)  500미터내_파출소개수   방범용CCTV  어린이보호구역CCTV  cluster
# 0                  0.014073     -0.844731  2.656181     1.887308        4
# 1                 -0.767403      0.569590  2.656181     1.887308        4
# 2                 -0.605672     -0.844731  2.656181     1.887308        4
# 3                 -0.546551      0.569590  2.656181     1.887308        1
# 4                 -0.265899     -0.844731  2.656181     1.887308        1
# ..                      ...           ...       ...          ...      ...
# 288               -0.424573      0.569590  0.751136    -1.555691        0
# 289               -0.987576      0.569590  0.751136    -1.555691        0
# 290                0.096298     -0.844731  0.751136    -1.555691        0
# 291               -0.243814      0.569590  0.751136    -1.555691        2
# 292               -0.819728      0.569590  0.751136    -1.555691        0
#
# [293 rows x 9 columns]

# %%
total_sd['cluster'].value_counts()
final = pd.merge(total_sd,school_info,on='학교명',how='left')
final.head()
# Out:
#                 학교명  내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  \
# 0            개포고등학교   0.409061   0.576037     0.549747
# 1            경기고등학교   0.409061  -1.736001     0.549747
# 2          경기여자고등학교   0.409061   0.576037     0.549747
# 3          국립국악고등학교  -2.444625  -1.736001    -1.819017
# 4  단국대학교부속소프트웨어고등학교  -2.444625   0.576037    -1.819017
#
#    학교폭력_예방교육_평균교육시간(1학급당)  500미터내_파출소개수   방범용CCTV  어린이보호구역CCTV  cluster  \
# 0                0.014073     -0.844731  2.656181     1.887308        4
# 1               -0.767403      0.569590  2.656181     1.887308        4
# 2               -0.605672     -0.844731  2.656181     1.887308        4
# 3               -0.546551      0.569590  2.656181     1.887308        1
# 4               -0.265899     -0.844731  2.656181     1.887308        1
#
#          학교코드
# 0  S010000373
# 1  S010000375
# 2  S010000376
# 3  S000003540
# 4  S010000581

# %%
Alleviate_score = final.groupby('cluster').mean()

# %% [markdown]
# ## 결과해석
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **CCTV 빈약 => 1, 3, 2, 4, 0**
#
# **상담 체계 빈약 => 4, 0, 3, 1, 2**
#
# - cluster 0 : 학내외 상담, 예방교육 체계가 빈약. 학교 주변 파출소 적음 CCTV 개수 매우 많은 학교
# - cluster 1 : 학내외 상담, 예방교육 체계가 갖추어져 있음. 학교 주변 파출소 매우 많음. CCTV 개수 매우 적은 학교
# - cluster 2 : 학내외 상담, 예방교육 체계가 갖추어져 있음. 학교 주변 파출소 매우 적음. CCTV 상대적으로 적은 학교
# - cluster 3 : 학내 상담 체계 갖추었으나 학외 상담 빈약. 학교 주변 파출소 상대적으로 적음. CCTV 상대적으로 적은 학교
# - cluster 4 : 학내 상담, 예방교육 체계가 매우 빈약. 학교 주변 파출소 상대적으로 적음. CCTV 상대적으로 적은 학교

# %% [markdown]
# # 경감지표 점수 산출

# %% [markdown]
# ## 1차 점수 산출

# %%
Alleviate_score['CCTV점수'] = Alleviate_score['방범용CCTV']+Alleviate_score['어린이보호구역CCTV']

# %%
Alleviate_score
# Out:
#          내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  학교폭력_예방교육_평균교육시간(1학급당)  \
# cluster
# 0         0.409061   0.576037     0.521208               -0.422457
# 1        -2.444625  -0.348778    -1.167607               -0.126516
# 2         0.409061  -1.736001     0.038837               -0.084887
# 3         0.409061   0.538134    -0.032736                0.783062
# 4         0.310658   0.376723     0.059658               -0.057121
#
#          500미터내_파출소개수   방범용CCTV  어린이보호구역CCTV    CCTV점수
# cluster
# 0           -0.452811 -0.314649    -0.504834 -0.819482
# 1            0.039220  0.225164     0.315079  0.540243
# 2           -0.040509 -0.290640    -0.232674 -0.523314
# 3            0.986930 -0.518482    -0.619618 -1.138100
# 4           -0.381419  1.095850     1.361398  2.457248

# %%
final['CCTV점수'] = final['방범용CCTV']+final['어린이보호구역CCTV']

# %%
rank = Alleviate_score.sort_values('CCTV점수').index
final['score_1st'] = ''
for i in range(len(final)):
    if final['cluster'][i]==rank[0]:
        final['score_1st'][i]=0.2
    elif final['cluster'][i]==rank[1]:
        final['score_1st'][i]=0.4
    elif final['cluster'][i]==rank[2]:
        final['score_1st'][i]=0.6
    elif final['cluster'][i]==rank[3]:
        final['score_1st'][i]=0.8
    elif final['cluster'][i]==rank[4]:
        final['score_1st'][i]=1

# %%
print(len(final.loc[final['score_1st']==0.2]))
print(len(final.loc[final['score_1st']==0.4]))
print(len(final.loc[final['score_1st']==0.6]))
print(len(final.loc[final['score_1st']==0.8]))
print(len(final.loc[final['score_1st']==1]))
# Out:
# 61
# 83
# 51
# 40
# 58

# %%
final.to_csv('final.csv',encoding='cp949')

# %%
dd = pd.read_csv('final.csv',encoding='cp949')
dd
# Out:
#      Unnamed: 0               학교명  내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  \
# 0             0            개포고등학교   0.409061   0.576037     0.549747
# 1             1            경기고등학교   0.409061  -1.736001     0.549747
# 2             2          경기여자고등학교   0.409061   0.576037     0.549747
# 3             3          국립국악고등학교  -2.444625  -1.736001    -1.819017
# 4             4  단국대학교부속소프트웨어고등학교  -2.444625   0.576037    -1.819017
# ..          ...               ...        ...        ...          ...
# 288         288          무학여자고등학교   0.409061   0.576037     0.549747
# 289         289          서울방송고등학교   0.409061   0.576037     0.549747
# 290         290            성수고등학교   0.409061   0.576037     0.549747
# 291         291          성수공업고등학교   0.409061  -1.736001     0.549747
# 292         292   한양대학교사범대학부속고등학교   0.409061   0.576037     0.549747
#
#      학교폭력_예방교육_평균교육시간(1학급당)  500미터내_파출소개수   방범용CCTV  어린이보호구역CCTV  cluster  \
# 0                  0.014073     -0.844731  2.656181     1.887308        4
# 1                 -0.767403      0.569590  2.656181     1.887308        4
# 2                 -0.605672     -0.844731  2.656181     1.887308        4
# 3                 -0.546551      0.569590  2.656181     1.887308        1
# 4                 -0.265899     -0.844731  2.656181     1.887308        1
# ..                      ...           ...       ...          ...      ...
# 288               -0.424573      0.569590  0.751136    -1.555691        0
# 289               -0.987576      0.569590  0.751136    -1.555691        0
# 290                0.096298     -0.844731  0.751136    -1.555691        0
# 291               -0.243814      0.569590  0.751136    -1.555691        2
# 292               -0.819728      0.569590  0.751136    -1.555691        0
#
#            학교코드    CCTV점수  score_1st
# 0    S010000373  4.543489        1.0
# 1    S010000375  4.543489        1.0
# 2    S010000376  4.543489        1.0
# 3    S000003540  4.543489        0.8
# 4    S010000581  4.543489        0.8
# ..          ...       ...        ...
# 288  S010000436 -0.804555        0.4
# 289  S010000585 -0.804555        0.4
# 290  S010005523 -0.804555        0.4
# 291  S010000592 -0.804555        0.6
# 292  S010000557 -0.804555        0.4
#
# [293 rows x 13 columns]

# %% [markdown]
# ## 2차 점수 산출

# %%
ingu = pd.read_csv('서울시_청소년인구통계.txt', delimiter='\t')[['지역','0세-18세']][2:].reset_index(drop=True)
ingu.columns=['구','청소년인구수']

# %%
police = pd.read_csv('경찰관서_2019.csv', encoding='cp949', index_col=0)[1:].reset_index(drop=True)
police['지구대_파출소_총합']=police['경찰서']+police['지구대파출소치안센터']

# %%
score_second = pd.merge(police,ingu,how='inner',on='구')

# %%
score_second['청소년인구수'] = score_second['청소년인구수'].str.replace(pat=r'[^A-Za-z0-9]', repl= r'', regex=True)
score_second['청소년인구수']= pd.to_numeric(score_second['청소년인구수'])

# %%
score_second['구당_청소년수'] = round(score_second['청소년인구수'] / score_second['지구대_파출소_총합'],2)
score_second = score_second[['구','구당_청소년수']]

# %%
temp=pd.read_csv('서울시고등학교_기본정보.csv',encoding='cp949')[['지역','학교명']]
temp.columns=['구','학교명']

# %%
score_second = pd.merge(temp, score_second, how='inner', on='구')

# %%
score_second
# Out:
#        구         학교명  구당_청소년수
# 0    강남구    국립국악고등학교  3898.57
# 1    강남구      개포고등학교  3898.57
# 2    강남구      경기고등학교  3898.57
# 3    강남구    경기여자고등학교  3898.57
# 4    강남구     압구정고등학교  3898.57
# ..   ...         ...      ...
# 315  강북구    창문여자고등학교  2322.33
# 316  강북구    혜화여자고등학교  2322.33
# 317  강북구  성암국제무역고등학교  2322.33
# 318  강북구     삼각산고등학교  2322.33
# 319  강북구      미양고등학교  2322.33
#
# [320 rows x 3 columns]

# %%
Alleviate_score_2nd = pd.merge(final, score_second,how='left',on='학교명')
Alleviate_score_2nd
# Out:
#                   학교명  내부상담_실시여부  외부상담_실시여부  wee클래스_운영여부  \
# 0              개포고등학교   0.409061   0.576037     0.549747
# 1              경기고등학교   0.409061  -1.736001     0.549747
# 2            경기여자고등학교   0.409061   0.576037     0.549747
# 3            국립국악고등학교  -2.444625  -1.736001    -1.819017
# 4    단국대학교부속소프트웨어고등학교  -2.444625   0.576037    -1.819017
# ..                ...        ...        ...          ...
# 288          무학여자고등학교   0.409061   0.576037     0.549747
# 289          서울방송고등학교   0.409061   0.576037     0.549747
# 290            성수고등학교   0.409061   0.576037     0.549747
# 291          성수공업고등학교   0.409061  -1.736001     0.549747
# 292   한양대학교사범대학부속고등학교   0.409061   0.576037     0.549747
#
#      학교폭력_예방교육_평균교육시간(1학급당)  500미터내_파출소개수   방범용CCTV  어린이보호구역CCTV  cluster  \
# 0                  0.014073     -0.844731  2.656181     1.887308        4
# 1                 -0.767403      0.569590  2.656181     1.887308        4
# 2                 -0.605672     -0.844731  2.656181     1.887308        4
# 3                 -0.546551      0.569590  2.656181     1.887308        1
# 4                 -0.265899     -0.844731  2.656181     1.887308        1
# ..                      ...           ...       ...          ...      ...
# 288               -0.424573      0.569590  0.751136    -1.555691        0
# 289               -0.987576      0.569590  0.751136    -1.555691        0
# 290                0.096298     -0.844731  0.751136    -1.555691        0
# 291               -0.243814      0.569590  0.751136    -1.555691        2
# 292               -0.819728      0.569590  0.751136    -1.555691        0
#
#            학교코드    CCTV점수 score_1st    구  구당_청소년수
# 0    S010000373  4.543489         1  강남구  3898.57
# 1    S010000375  4.543489         1  강남구  3898.57
# 2    S010000376  4.543489         1  강남구  3898.57
# 3    S000003540  4.543489       0.8  강남구  3898.57
# 4    S010000581  4.543489       0.8  강남구  3898.57
# ..          ...       ...       ...  ...      ...
# 288  S010000436 -0.804555       0.4  성동구  2343.44
# 289  S010000585 -0.804555       0.4  성동구  2343.44
# 290  S010005523 -0.804555       0.4  성동구  2343.44
# 291  S010000592 -0.804555       0.6  성동구  2343.44
# 292  S010000557 -0.804555       0.4  성동구  2343.44
#
# [293 rows x 14 columns]

# %%
Alleviate_score_2nd['score_2nd']=''
for i in range(len(Alleviate_score_2nd)):
    for k in range(5):
        rank_lis = sorted(list(set(Alleviate_score_2nd[Alleviate_score_2nd['cluster']==k]['구당_청소년수'])), reverse=True) 
        for j in range(len(rank_lis)): #내림차순 정렬한 리스트의 인덱스 순서대로 적은 점수를 차감
            if Alleviate_score_2nd['구당_청소년수'][i] == rank_lis[j]:
                Alleviate_score_2nd['score_2nd'][i] = round((Alleviate_score_2nd['score_1st'][i]-(j/len(rank_lis))*0.2)*10,2) # 점수 만점을 10점으로 만들기

# %%
Alleviate_score_2nd.columns
# Out:
# Index(['학교명', '내부상담_실시여부', '외부상담_실시여부', 'wee클래스_운영여부',
#        '학교폭력_예방교육_평균교육시간(1학급당)', '500미터내_파출소개수', '방범용CCTV', '어린이보호구역CCTV',
#        'cluster', '학교코드', 'CCTV점수', 'score_1st', '구', '구당_청소년수', 'score_2nd'],
#       dtype='object')

# %%
Alleviate_fin = Alleviate_score_2nd[['학교코드','학교명','구','score_2nd']]
Alleviate_fin.sort_values(by=['score_2nd'], ascending=[False])
# Out:
#            학교코드          학교명    구 score_2nd
# 146  S010000397     광영여자고등학교  양천구      10.0
# 158  S010000549      한가람고등학교  양천구      10.0
# 157  S010000537     진명여자고등학교  양천구      10.0
# 156  S010000489       양천고등학교  양천구      10.0
# 154  S010005285       신서고등학교  양천구      10.0
# ..          ...          ...  ...       ...
# 203  S010000604   서울의료보건고등학교   중구      0.11
# 205  S010000591     성동공업고등학교   중구      0.11
# 206  S010000617  성동글로벌경영고등학교   중구      0.11
# 207  S010000516     이화여자고등학교   중구      0.11
# 210  S010000601     한양공업고등학교   중구      0.11
#
# [293 rows x 4 columns]
