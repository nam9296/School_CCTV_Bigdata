# %%
ID = ''
KEY = ''

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = ID
client_secret = KEY
encText = urllib.parse.quote("학교폭력")

def create_url(start):
    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText+'&display=100'+ '&start=' + str(start)
    return url
url = create_url(1)


request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    results=response_body.decode('utf-8')
    print(response_body.decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Thu, 06 May 2021 21:31:58 +0900",
# "total": 319798,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "장애인 특수<b>학교</b>에서 <b>학교폭력</b>..경찰 수사",
# "originallink": "https://jejumbc.com/article/ZQcAXlewD1M",
# "link": "https://jejumbc.com/article/ZQcAXlewD1M",
# "description": "도내 한 장애인 특수<b>학교</b>에서 <b>학교폭력</b> 사건이 발생해 경찰이 수사에 나섰습니다. 피해 학생 학부모에 따르면 특수<b>학교</b> 학생인 18살 A양은 지난달 말 통학버스 안에서 같은 <b>학교</b> 학생에에 괴롭힘을 당해 피멍과 찰과상을... ",
# "pubDate": "Thu, 06 May 2021 21:10:00 +0900"
#
# },
# {
# "title": "[인터뷰]'정상 목표 리빌딩하는' 석진욱 OK금융그룹 감독",
# "originallink": "http://www.kyeongin.com/main/view.php?key=20210506010001253",
# "link": "http://www.kyeongin.com/main/view.php?key=20210506010001253",
# "description": "/KOVO 제공 용병 지명권 획득 10% 행운잡아주전 라이트 조재성 성장 주목학폭 관련 선수들은 반성·사과2020~2021시즌 좋은 성적을 유지하다가 <b>학교폭력</b> 이슈로 인해 팀이 흔들리면서 정규리그 4위로 마친 남자 프로배구... ",
# "pubDate": "Thu, 06 May 2021 21:00:00 +0900"
#
# },
# {
# "title": "‘당심보다 민심’ 앞세운 김부겸, 친문·청와대에 쓴소리도",
# ...

# %%
response_body.decode('utf-8')
# Out:
# '{\n"lastBuildDate": "Thu, 06 May 2021 21:31:58 +0900",\n"total": 319798,\n"start": 1,\n"display": 100,\n"items": [\n{\n"title": "장애인 특수<b>학교</b>에서 <b>학교폭력</b>..경찰 수사",\n"originallink": "https://jejumbc.com/article/ZQcAXlewD1M",\n"link": "https://jejumbc.com/article/ZQcAXlewD1M",\n"description": "도내 한 장애인 특수<b>학교</b>에서 <b>학교폭력</b> 사건이 발생해 경찰이 수사에 나섰습니다. 피해 학생 학부모에 따르면 특수<b>학교</b> 학생인 18살 A양은 지난달 말 통학버스 안에서 같은 <b>학교</b> 학생에에 괴롭힘을 당해 피멍과 찰과상을... ",\n"pubDate": "Thu, 06 May 2021 21:10:00 +0900"\n\n},\n{\n"title": "[인터뷰]\'정상 목표 리빌딩하는\' 석진욱 OK금융그룹 감독",\n"originallink": "http://www.kyeongin.com/main/view.php?key=20210506010001253",\n"link": "http://www.kyeongin.com/main/view.php?key=20210506010001253",\n"description": "/KOVO 제공 용병 지명권 획득 10% 행운잡아주전 라이트 조재성 성장 주목학폭 관련 선수들은 반성·사과2020~2021시즌 좋은 성적을 유지하다가 <b>학교폭력</b> 이슈로 인해 팀이 흔들리면서 정규리그 4위로 마친 남자 프로배구... ",\n"pubDate": "Thu, 06 May 2021 21:00:00 +0900"\n\n},\n{\n"title": "‘당심보다 민심’ 앞세운 김부겸, 친문·청와대에 쓴소리도",\n"originallink": "https://hankookilbo
# ...

# %%
import json
json.loads(results)
# Out:
# {'lastBuildDate': 'Thu, 06 May 2021 21:31:58 +0900',
#  'total': 319798,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '장애인 특수<b>학교</b>에서 <b>학교폭력</b>..경찰 수사',
#    'originallink': 'https://jejumbc.com/article/ZQcAXlewD1M',
#    'link': 'https://jejumbc.com/article/ZQcAXlewD1M',
#    'description': '도내 한 장애인 특수<b>학교</b>에서 <b>학교폭력</b> 사건이 발생해 경찰이 수사에 나섰습니다. 피해 학생 학부모에 따르면 특수<b>학교</b> 학생인 18살 A양은 지난달 말 통학버스 안에서 같은 <b>학교</b> 학생에에 괴롭힘을 당해 피멍과 찰과상을... ',
#    'pubDate': 'Thu, 06 May 2021 21:10:00 +0900'},
#   {'title': "[인터뷰]'정상 목표 리빌딩하는' 석진욱 OK금융그룹 감독",
#    'originallink': 'http://www.kyeongin.com/main/view.php?key=20210506010001253',
#    'link': 'http://www.kyeongin.com/main/view.php?key=20210506010001253',
#    'description': '/KOVO 제공 용병 지명권 획득 10% 행운잡아주전 라이트 조재성 성장 주목학폭 관련 선수들은 반성·사과2020~2021시즌 좋은 성적을 유지하다가 <b>학교폭력</b> 이슈로 인해 팀이 흔들리면서 정규리그 4위로 마친 남자 프로배구... ',
#    'pubDate': 'Thu, 06 May 2021 21:00:00 +0900'},
#   {'title': '‘당심보다 민심’ 앞세운 김부겸, 친문·청와대에 쓴소리도',
# ...

# %%
json.loads(results).keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
items=json.loads(results)['items']

# %%
items[1]
# Out:
# {'title': "[인터뷰]'정상 목표 리빌딩하는' 석진욱 OK금융그룹 감독",
#  'originallink': 'http://www.kyeongin.com/main/view.php?key=20210506010001253',
#  'link': 'http://www.kyeongin.com/main/view.php?key=20210506010001253',
#  'description': '/KOVO 제공 용병 지명권 획득 10% 행운잡아주전 라이트 조재성 성장 주목학폭 관련 선수들은 반성·사과2020~2021시즌 좋은 성적을 유지하다가 <b>학교폭력</b> 이슈로 인해 팀이 흔들리면서 정규리그 4위로 마친 남자 프로배구... ',
#  'pubDate': 'Thu, 06 May 2021 21:00:00 +0900'}

# %%
items[1]['title']
# Out:
# "[인터뷰]'정상 목표 리빌딩하는' 석진욱 OK금융그룹 감독"

# %%
items[1]['description']
# Out:
# '/KOVO 제공 용병 지명권 획득 10% 행운잡아주전 라이트 조재성 성장 주목학폭 관련 선수들은 반성·사과2020~2021시즌 좋은 성적을 유지하다가 <b>학교폭력</b> 이슈로 인해 팀이 흔들리면서 정규리그 4위로 마친 남자 프로배구... '

# %%
# f = open('크롤링.txt','a',encoding='utf8')
# f.write('안녕하세요')
# f.close()

# %% [markdown]
# 1. url 생성후
# 2. API request 보내서
# 3. 결과를 json으로 반환
# 4. 100개의 항목에 대해서 하나씩 제목과 description을 따와서 txt파일에 써주기

# %%
for i in range(1,1001,100):
    url = create_url(i)


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        results=response_body.decode('utf-8')
        items=json.loads(results)['items']
        for item in items:
            f=open('학교폭력news123.txt','a',encoding='utf-8')
            title = item['title']
            description = item['description']
            
            title= title.replace("<b>", " ")
            title= title.replace("</b>", " ")
            title= title.replace("&quot;", " ")
            
            description= description.replace("<b>", " ")
            description= description.replace("</b>", " ") 
            description= description.replace("...", "")
            description= description.replace("&quot;", " ")
            
            f.write(title+ '\n')
            f.write(description+ '\n')
            f.close()
